# %% [markdown]
# <a href="https://colab.research.google.com/github/Lib0823/Python_Basic-STUDY/blob/main/STEP9_%EC%98%88%EC%99%B8%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # STEP 9. 예외 처리

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **01. 오류**
# - 파이썬의 오류는 두 가지 종류 존재
# > - 구문 오류
# > - 예외 (런타임 오류)

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. 구문 오류**
# - 프로그램 실행 전에 발생하는 오류

# %%
# 문자열 닫힘 따옴표 문제로 오류 발생
# SyntaxError는 구문에 문제가 있어서 프로그램이 실행조차 안 된 경우
print("파이썬 프로그래밍)
# Out:
#   File "/tmp/ipykernel_41166/1115589760.py", line 3
#     print("파이썬 프로그래밍)
#           ^
# SyntaxError: unterminated string literal (detected at line 3)

# %%
# 문자열 닫힘 따옴표 문제를 해결하여 오류 해결
# 해당 오류는 해결을 해줘야만 프로그램을 실행할 수 있음
print("파이썬 프로그래밍")
# Out:
# 파이썬 프로그래밍

# %% [markdown]
# ### **2. 예외 (런타임 오류)**
# - 프로그램 실행 중에 발생하는 오류

# %%
# myList 변수에 리스트 선언 -> 프로그램 실행됨
# myList[7]은 myList에서 얻을 수 없는 값으로 오류 발생
myList = [1, 2, 3, 4]

myList[7]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_41166/26631153.py in <cell line: 0>()
#       3 myList = [1, 2, 3, 4]
#       4
# ----> 5 myList[7]
#
# IndexError: list index out of range

# %%
# myList 변수에 리스트 선언 -> 프로그램 실행됨
# myList[3]은 myList에서 얻을 수 있는 값으로 수정하여 오류 해결
# 또는 예외 처리를 통해 문제를 해결할 수 있음!
myList = [1, 2, 3, 4]

myList[3]

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **02. 예외 처리 기법**
# - 예외 처리는 예외를 해결하는 것
# - 프로그램이 강제로 종료되는 일 없이 예외 처리를 하고 정상적으로 종료

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. try - except 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# 프로그램이 강제로 종료되는 일 없이 예외 처리를 하고 정상적으로 종료
try:
  myList = [1, 2, 3, 4]
  myList[7]
except:
  print("예외 발생!")
# Out:
# 예외 발생!

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# except 문 안에 pass 키워드를 넣으면 아무것도 출력하지 않고 강제 종료도 막을 수 있음
try:
  myList = [1, 2, 3, 4]
  myList[7]
except:
  pass

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. try - except - else 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# 문자 입력 시 예외 발생
try:
  Number = int(input("숫자 입력 :"))
except:
  print("예외 발생!")
else:
  print("입력한 숫자는 ", Number, "입니다.")
# Out:
# 숫자 입력 :ㅁㅇ;니ㅏ러
# 예외 발생!

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# 숫자 입력시 프로그램 정상 작동
try:
  Number = int(input("숫자 입력 :"))
except:
  print("예외 발생!")
else:
  print("입력한 숫자는 ", Number, "입니다.")
# Out:
# 숫자 입력 :234324
# 입력한 숫자는  234324 입니다.

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. try - except - finally 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 문자 입력 시 예외 발생
try:
  Number = int(input("숫자 입력 :"))
except:
  print("예외 발생!")
finally:
  print("finally 문은 무조건 실행됨.")
# Out:
# 숫자 입력 :ㅁㄴㅇㄹㅁㄴㅇㄹ
# 예외 발생!
# finally 문은 무조건 실행됨.

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 숫자 입력시 프로그램 정상 작동
try:
  Number = int(input("숫자 입력 :"))
except:
  print("예외 발생!")
finally:
  print("finally 문은 무조건 실행됨.")
# Out:
# 숫자 입력 :235532
# finally 문은 무조건 실행됨.

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP9_예외처리_8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **4. try - except - else - finally 구문**

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 문자 입력 시 예외 발생
try:
  Number = int(input("숫자 입력 :"))
except:
  print("예외 발생!")
else:
  print("입력한 숫자 ", Number, "입니다.")
finally:
  print("finally 문은 무조건 실행됨.")
# Out:
# 숫자 입력 :slkdjf
# 예외 발생!
# finally 문은 무조건 실행됨.

# %%
# try 문 안에는 예외가 발생할 가능성이 있는 모든 코드 삽입
# except 문 안에는 예외가 발생했을 때 실행할 모든 코드 삽입
# else 문 안에는 예외가 발생하지 않았을 때 실행할 코드 삽입
# finally 문 안에는 예외 발생 여부와 상관없이 무조건 실행할 코드 삽입
# 숫자 입력시 프로그램 정상 작동
try:
  Number = int(input("숫자 입력 :"))
except:
  print("예외 발생!")
else:
  print("입력한 숫자 ", Number, "입니다.")
finally:
  print("finally 문은 무조건 실행됨.")
# Out:
# 숫자 입력 :346
# 입력한 숫자  346 입니다.
# finally 문은 무조건 실행됨.
