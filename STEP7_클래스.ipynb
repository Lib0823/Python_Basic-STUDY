# %% [markdown]
# <a href="https://colab.research.google.com/github/Lib0823/Python_Basic-STUDY/blob/main/STEP7_%ED%81%B4%EB%9E%98%EC%8A%A4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **STEP 7. 클래스**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **01. 클래스**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. 객체 지향 프로그래밍**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. 클래스와 객체**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. 클래스 선언**
# - 클래스 선언
# > - class 키워드를 사용하여 클래스 선언
# > - ```
# class 클래스 이름 :
#           클래스 내용
# ```

# %%
# 곰돌이 젤리 클래스 생성
class BearJelly:
  pass

# %% [markdown]
# ### **4. 객체와 인스턴스**
# - 객체 (object)
# > - 'red_jelly = TeddyBearJelly()'로 만든 red_jelly는 객체
#
# - 인스턴스 (instance)
# > - red_jelly는 TeddyBearJelly의 인스턴스
#
# - 인스턴스 생성
# > - 클래스 기반으로 만들어진 객체를 인스턴스라고 부름
# > - 클래스 인스턴스를 생성하려면 클래스 이름 뒤에 ( )괄호를 적으면 됨
# > - ```
# 인스턴스 이름 = 클래스 이름()
# ```

# %%
# 빨간색, 노란색, 초록색 젤리 객체 생성
# 각 jelly들은 TeddyBearJelly의 인스턴스
red_jelly = BearJelly()
green_jelly = BearJelly()

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# - 메소드 (method)
# > - 클래스가 가지고 있는 함수를 의미
# > - ```
# class 클래스 이름 :
#         def 메소드 이름(self, 추가적인 매개변수) :
#             pass
# ```

# %%
# 곰돌이 젤리 클래스 선언
# 'set_info' 함수 선언 : 젤리 생성시 필요한 속성 입력
# 'print_info' 함수 선언 : 젤리 속성 출력
class BearJelly:
  # python은 필드 선언을 안해도 된다..
  def setInfo(self, color, taste):
    self.color = color
    self.taste = taste

  def printInfo(self):
    print("==============")
    print("Color: ", self.color)
    print("Taste: ", self.taste)
    print("==============")

# %%
# 젤리 객체 선언
yellow_jelly = BearJelly()

# %%
# 젤리 객체의 필요한 속성 입력
# 메소드 사용
yellow_jelly.setInfo("yellow", "lemon")

# %%
# yellow_jelly의 속성에 접근하는 방법
print(yellow_jelly.color)
yellow_jelly.taste
# Out:
# yellow
# 'lemon'

# %%
# 젤리 객체 내용 출력
# 메소드 사용
yellow_jelly.printInfo()
# Out:
# ...
# Color:  yellow
# Taste:  lemon
# ...

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_9.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **6. 생성자**
# - 생성자 (constructor)
# > - 클래스로부터 인스턴스가 생성될 때 자동으로 실행되는 함수
# > - 클래스를 실행하면 가장 먼저 생성자인 '\_\_init__' 함수가 호출
# > - '\_\_init__' 함수는 인스턴스의 생성과 동시에 필요한 정보를 입력받도록 구현하는 역할
# > - ```
# class 클래스 이름 :
#         def __init__(self, 추가적인 매개변수) :
#             pass
# ```

# %%
# 메소드는 클래스 내부의 함수를 의미
# '5. 메소드'에서 구현했던 'TeddyBearJelly' 클래스의
# 'set_info( )' 함수가 데이터를 입력받는 역할 수행함
# 'set_info' 메소드를 '__init__' 메소드로 이름 변경

# 곰돌이 젤리 클래스 선언
# 생성자 선언
class BearJelly:
  def __init__(self, color, taste):
    self.color = color
    self.taste = taste

# %%
# 젤리 리스트 선언
jelly = [
    BearJelly("red", "strawberry"),
    BearJelly("yellow", "lemon"),
    BearJelly("green", "apple")
]

# %%
# jelly 인스턴스의 속성에 접근하는 방법
print(jelly[0].color)
print(jelly[0].taste)
# Out:
# red
# strawberry

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_10.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **7. 상속**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_11.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **7-1. 상속 선언**

# %% [markdown]
# #### **7-2. 메소드 오버라이딩**

# %%
# 부모 클래스 선언
class Jelly:
  def __init__(self, color, taste):
    self.color = color
    self.taste = taste

  def printInfo(self):
    print("부모 클래스")
    print("젤리")

# 자식 클래스 선언
# 자식 클래스를 선언할 때 소괄호로 부모 클래스를 포함
# 일반적인 메소드 오버라이딩
# 자식 클래스에서 생성된 메소드로 부모 클래스의 메소드 무시
class BearJelly(Jelly): #부모에 생성자가 있어서 자식은 없어도 됨
  def printInfo(self):
    print("자식 클래스")
    print("곰돌이 젤리")
    print("Taste:", self.taste)
    print("Color:", self.color)

# 자식 클래스 선언
# 자식 클래스를 선언할 때 소괄호로 부모클래스를 포함
# 부모 메소드 호출
# super() 키워드를 사용하여 자식 클래스에서 부모 클래스 호출 가능
class HeartJelly(Jelly):
  def printInfo(self):
    super().printInfo()
    print("자식 클래스")
    print("하트 젤리")
    print("Taste:", self.taste)
    print("Color:", self.color)

# %%
# 부모 클래스로 객체 생성
# 부모 클래스의 print_info() 함수
red_jelly = Jelly("red", "strawberry")
red_jelly.printInfo()
# Out:
# 부모 클래스
# 젤리

# %%
# 자식 클래스로 객체 생성
# 자식 클래스의 print_info() 함수
# 자식 클래스에서 생성된 메소드로 부모 클래스의 메소드 무시
yellow_jelly = BearJelly("yellow", "lemon")
yellow_jelly.printInfo()
# Out:
# 자식 클래스
# 곰돌이 젤리
# Taste: lemon
# Color: yellow

# %%
# 자식 클래스로 객체 생성
# 자식 클래스의 print_info() 함수
# super() 키워드를 사용하여 자식 클래스에서 부모 클래스 호출 가능
green_jelly = HeartJelly("green", "apple")
green_jelly.printInfo()
# Out:
# 부모 클래스
# 젤리
# 자식 클래스
# 하트 젤리
# Taste: apple
# Color: green

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP7_클래스_12.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **7-3. 다중 상속**
# - 자식 클래스를 선언할 때 소괄호로 원하는 부모클래스를 모두 포함
# - 다중 상속의 개수 제한 없음
# - ```
#     class 부모 클래스1:
#           pass
#
#     class 부모 클래스2:
#           pass
#
#     class 자식 클래스(부모 클래스1, 부모 클래스2):
#           pass
