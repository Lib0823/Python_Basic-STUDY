# %% [markdown]
# <a href="https://colab.research.google.com/github/Lib0823/Python_Basic-STUDY/blob/main/STEP6_%ED%95%A8%EC%88%98.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **STEP 6. 함수**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **01. 함수 (function)**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. 기본 구조**
# - 반복적으로 사용되는 기능을 함수로 사용
# - 함수는 def 키워드 사용하여 생성

# %%
# add 함수 정의
# 매개변수 x와 y를 입력으로 받기
# x + y 코드를 계산하여 출력
def add(x, y):
  return x + y

# %%
# add 함수를 호출하여 인수로 3과 6 입력
# z값에 함수의 결과를 출력하여 저장
z = add(3, 6)
print(z)
# Out:
# 9

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. 매개변수 (parameter)**
# - 함수에 입력으로 전달된 값을 받는 변수

# %% [markdown]
# #### **2-1. 디폴트 매개변수**
# - 매개변수의 값이 입력되지 않으면 디폴트 값으로 자동 입력
# - 매개변수가 여러 개인 경우 뒤의 매개변수부터 디폴트 값을 가질 수 있음

# %%
# add 함수 정의
# 매개변수 x와 y를 입력으로 받기
# y는 디폴트 매개변수로 입력이 없다면 디폴트 값으로 자동 입력
# x + y 코드를 계산하여 출력
def add(x, y=3):
  return x + y

# %%
# add 함수를 호출하여 인수로 3과 6 입력
# z값에 함수의 결과를 출력하여 저장
# y 매개변수에 값을 입력하면 그대로 입력
z = add(3, 6)
print(z)
# Out:
# 9

# %%
# add 함수를 호출하여 인수로 3만 입력
# z값에 함수의 결과를 출력하여 저장
# y 매개변수에 입력이 없다면 디폴트 값으로 자동 입력
z = add(3)
print(z)
# Out:
# 6

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **2-2. 가변 매개변수**
# - 원하는 만큼의 인자를 받을 수 있는 함수를 가변 매개변수를 사용한다고 표현
# - \*매개변수 : 가변 매개변수는 매개변수 앞에 *를 붙임

# %%
# values라는 가변 매개변수
# menu 함수를 통해 카페 메뉴 출력
# 가변 매개변수는 리스트처럼 사용
def menu(*values):
  print("카페 메뉴는?")

  for val in values:
    print(val)

# %%
# 정의한 menu 함수 호출
# 인수로 4가지 메뉴 입력
menu('코코아', '캐모마일', '얼그레이')
# Out:
# 카페 메뉴는?
# 코코아
# 캐모마일
# 얼그레이

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **2-3. 키워드 매개변수**
# - 매개변수의 이름을 지정해서 입력하여 함수 호출
# - 키워드 매개변수를 넘겨줄 때 매개변수의 순서와 상관없이 나열 가능

# %%
# add 함수 정의
# 매개변수 x와 y, 그리고 z는 디폴트 매개변수
# x + y + z 코드를 계산하여 출력
def add(x=1, y=2, z=3):
  return x+y+z

# %%
# 키워드 매개변수를 사용하여 add 함수 호출
# 키워드 매개변수를 넘겨줄 때 매개변수의 순서와 상관없이 나열 가능
# 키워드 매개변수는 x, y, z
add(y=5, z=5, x=1)
# Out:
# 11

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP6_함수_7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. 인수 (arguments)**
# - 함수를 호출할 때 전달하는 입력 값
#
# - ```
# 함수(인수1, 인수2)
# ```

# %%
# add 함수 정의
# 매개변수 x와 y를 입력으로 받기
# x + y 코드를 계산하여 출력
def add(x, y):
  return x + y

# %%
# add 함수를 호출하여 인수로 3과 6 입력
# 인수는 함수를 호출할 때 전달하는 입력 값
add(3, 6)
# Out:
# 9

# %% [markdown]
# ### **4. 리턴 (return)**
# - 함수를 호출한 곳으로 결과 값 반환
# - ```
# def 함수이름(매개변수)
#       실행문
#       return 되돌려 주는 결과 값
# ```
#
# - ```
# 변수 = 함수이름(인수)
# ```

# %% [markdown]
# #### **4-1. 한 개의 리턴 값**

# %%
# returnTest 함수 정의하고 함수를 호출하여 return 값 확인
def returnTest():
  return "되돌려 주는 결과 값~"

val = returnTest()
print(val)
# Out:
# 되돌려 주는 결과 값~

# %% [markdown]
# #### **4-2. 두 개의 리턴 값**

# %%
# returnTest 함수 정의하고 함수를 호출하여 return 값 확인
# 반환되는 두 개의 값을 차례대로 value1, value2에 저장하여 출력
def returnTest():
  a = 3
  b = 4
  return a, b

val1, val2 = returnTest() #파이썬은 이렇게 변수 할당이 가능함..
print(val1)
print(val2)
# Out:
# 3
# 4
