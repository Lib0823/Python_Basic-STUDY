# %% [markdown]
# <a href="https://colab.research.google.com/github/Lib0823/Python_Basic-STUDY/blob/main/STEP4_%EC%A1%B0%EA%B1%B4%EB%AC%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# # **STEP 4. 조건문**
# - 조건문은 참과 거짓을 판단하는 문장

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ## **01. if 조건문**

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **1. if 문**
# - 조건이 참일 경우 실행
# - 조건이 거짓일 경우 패스

# %%
# "Selena 수업을 들으면 파이썬을 정복할 수 있다."
# 위의 문장을 파이썬 조건문으로 표현

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_4.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# #### **1-1. 들여쓰기**
# - if 문에 속한 모든 문장은 들여쓰기 필수

# %% [markdown]
# #### **1-2. 콜론 (:)**
# - if 조건문 뒤에는 반드시 콜론(:)을 삽입
# - 파이썬 문법 구조

# %%
# "카페인이 첨가된 종류는 아메리카노, 카페라떼, 콜드브루가 있다."
# 위의 문장을 파이썬 조건문으로 표현

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_5.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **2. else 문**
# - else 문은 if 문 뒤에 사용하며, if 문 조건이 거짓일 때 실행되는 부분

# %%
# "Selena 수업을 들으면 파이썬을 정복할 수 있고 Selena 수업을 듣지 않으면 파이썬을 정복할 수 없다."
# 위의 문장을 파이썬 조건문으로 표현

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_6.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **3. elif 문**
# - elif 문은 세 개 이상의 조건을 연결할 때 사용

# %%
# class를 공지하는 식

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_7.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **4. in / not in 연산자**
# - 데이터 안에 찾고자 하는 것이 있는지 없는지 확인하는 연산자

# %%
# python 문자열에 k가 포함되어 있지 않다면 True, 포함 되어 있다면 False 출력

# %% [markdown]
# ### **5. pass 키워드**
# - 조건은 만족하지만 아무 일도 수행하고 싶지 않을 때 사용
# - 프로그래밍의 전체 골격을 잡아놓고, 내부에 처리할 내용은 추후에 만들고자 할 때 사용

# %%
# 바구니에 딸기가 없다면 pass

# %% [markdown]
# ![Selena_파이썬 프로그래밍_STEP4_조건문_8.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ### **6. 관계연산자**
# - 두 개의 값을 비교하여 그 값을 참 또는 거짓으로 판별하는 연산자
# > - ==
# > - !=
# > - <
# > - \>
# > - <=
# > - \>=

# %%
# a, b 변수 선언
a = 3
b = 1

# %%
# 관계연산자 결과 출력

# %% [markdown]
# ### **7. 논리연산자**
# - 논리 값을 판단해주는 연산자
# > - not (논리 부정) : 한 개의 값이 False면 결과 값으로 True 반환, True이면 결과 값으로 False 반환
# > - and (논리 곱) : 두 개의 값이모두 True인 경우에만 결과 값으로 True 반환, 나머지는 모두 False 반환
# > - or (논리 합) : 두 개의 값이 모두 False인 경우에만 결과 값으로 False 반환,
# 나머지는 모두 True 반환

# %%
# not (논리 부정) : 한 개의 값이 False면 결과 값으로 True 반환, True이면 결과 값으로 False 반환

# %%
# and (논리 곱) : 두 개의 값이모두 True인 경우에만 결과 값으로 True 반환, 나머지는 모두 False 반환

# %%
# or (논리 합) : 두 개의 값이 모두 False인 경우에만 결과 값으로 False 반환, 나머지는 모두 True 반환
